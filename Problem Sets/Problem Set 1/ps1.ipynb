# %%
#Q2: Code to generate random number bw 0 and 1
import random
a = random.random()
print(a)
# Out:
# 0.7596533922024208

# %%
#Q3: Generate a list of 100 random numbers
randList = []
for i in range(100):
    t = random.random()
    randList.append(t)
print(len(randList),"random numbers:")
print(randList)
# Out:
# 100 random numbers:
# ...
